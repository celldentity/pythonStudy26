# %%
## 리스트란 표 형식의 배열을 말한다.
# ids = ["kkw", "lhj", "ksb"]
# pws = ["1234", "4321", "4567"]
# names = ["김기원", "임효정", "김수빈"]
# 개발자끼리는 복수의 내용이 들어있는 변수(리스트)는 변수 이름뒤에 s를 적어준다.
# 리스트를 만들 때는 대괄호[] 로 감싸주고 쉼표, 로 구분한다.

# a = [] 빈 리스트를 생성한다. a = list()로도 생성이 가능하다.
# b = [1. 2. 3] 정수를 입력 할 수 있다.
# c = [1, 2, 'kkw', 'lhj']와 같이 혼용하여 넣을 수 있다. Java에서는 불가능하다. 보안상 위험해서 막아뒀다고 한다.
# d = [1, 2, ['kkw', '1234']] 2차원 리스트

# d 변수에서 kkw를 가져오고 싶으면??? d[2][0] 2차원 리스트에서 원하는 값을 가져오는 방법이다.
# 1차원 리스트에서 두 번째, 이차원 리스트 안에서 첫 번재. 즉 d[2][0]이 된다.
# f = [1.2. ['kkw', '1234', ['파이썬', '자바']]] 이건 3차원 배열이다.
# f변수에서 파이썬을 가지고 오고 싶으면? f[2][2][0]

# 리스트의 인덱싱 -> 문자열 인덱싱과 같다.
a = [1,2,3]
print(a)
a
print("2. " + str(type(a)))
# Out:
# [1, 2, 3]
# 2. <class 'list'>

# %%
a[0]+a[2]
# Out:
# 4

# %%
b = [1,2,3,['a','b','c']] # 2차원 리스트
b[3][2]
# Out:
# 'c'

# %%
## 리스트의 슬라이싱 -> 문자열의 슬라이싱과 같다.
c = [1, 2, 3, 4, 5, 6]
c[0:2] #인덱스 슬라이싱은 항상 마지막 값 -1 값이 나온다.
# Out:
# [1, 2]

# %%
## 리스트 더하기
d = [1,2,3]
e = [4,5,6]
f = d + e
print(f)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
## 리스트 곱하기
g = e*2
print(g)
# Out:
# [4, 5, 6, 4, 5, 6]

# %%
## 리스트 길이 구하기
len(g)
# Out:
# 6

# %%
## 리스트에 CRUD 기법을 적용해보자.
# Create 생성, 추가, 삽입
# Read 전체리스트보기, 1개 자료보기
# Update 자료 수정
# Delete 자료 삭제

# %%
## 리스트에 자료를 추가해보자
ids = ["kkw", "lhj", "ksb"] # 회원 id
ids.append("MBC")
print(ids)
# Out:
# ['kkw', 'lhj', 'ksb', 'MBC']

# %%
passwords = ["1234", "4321", "4567"]
passwords.append("8888")
print(passwords)
# Out:
# ['1234', '4321', '4567', '8888']

# %%
## 리스트에 있는 값 가져오기
ids.index("MBC")
# Out:
# 3

# %%
passwords[3] = '4486'
print(passwords)
# Out:
# ['1234', '4321', '4567', '4486']

# %%
## 3번재 인덱스의 암호를 삭제해본다.
passwords.remove("4486")
print(passwords)
# Out:
# ['1234', '4321', '4567']

# %%
## 메세지 없이 바로 지워지는 걸 막기 위해서 pop은 삭제되는 내용을 출력하고 삭제한다.
# passwords.pop() 맨 마지막 자료를 삭제한다.
# passwords.pop(2) 2번 인덱스에 있는 자료를 삭제한다.
passwords.pop(2)
# Out:
# '4567'

# %%
print(passwords)
# Out:
# ['1234', '4321']

# %%
run = True # 프로그램 동작중을 관리하는 변수

menu = """
===========================
MBC 아카데미 회원 관리 프로그램
===========================
1. 회원가입
2. 로그인
3. 회원보기
4. 내정보수정
5. 프로그램종료
"""

#사용할 리스트 변수를 생성한다.
sns = [1, 2] # 사용자 관리번호
ids = ["kkw", "lhj"] # 로그인용 아이디
passwords = ["1234", "4321"] # 로그인용 비밀번호
names = ["관리자", "임효정"] # 사용자명
emails = ["admin@mbc.com", "lhj@mbc.com"] # 이메일주소
admins = [True, False] # 관리자 유무 관리자 : True, 일반사용자 False


while run :
     print(menu)
     select = input("1~5 숫자를 입력하여 메뉴를 선택하세요 : ")
     if select == "1" :
         print("회원가입 메뉴에 진입하였습니다.")
         sn = input("사번을 입력하세요 : ")
         id = input("아이디를 입력하세요 : ")
         pw = input("암호를 입력하세요 : ")
         name = input("이름을 입력하세요 : ")
         email = input("이메일주소를 입력하세요 : ")
         admin = False

         print("입력된 값을 확인하시고 y를 누르면 가입됩니다.")
         print("이름 : " + name)
         print("id : " + id)
         print("pw : " + pw)
         if input("y/n : ") == "y":
             sns.append(sn)
             ids.append(id)
             passwords.append(pw)
             names.append(name)
             emails.append(email)
             admins.append(admin)
             print("입력이 완료되었습니다.")
         else:
             print("처음부터 다시 진행하세요!!!")


     elif select == "2" :
        print("로그인 메뉴에 진입하였습니다.")
        id_input = input("id를 입력하세요: ")
        if id_input in ids:
                idx = ids.index(id_input)
                pw_input = input("pw를 입력하세요: ")



     elif select == "3" :
        print("회원 정보 보기 메뉴에 진입하였습니다.")
     elif select == "4" :
        print("내정보 수정 페이지 입니다.")
     elif select == "5" :
        print("회원가입 프로그램이 종료됩니다.")
     else:
        print("1~5 사이 값을 입력하세요!!!")
# Out:
# ...
# MBC 아카데미 회원 관리 프로그램
# ...
# 1. 회원가입
# 2. 로그인
# 3. 회원보기
# 4. 내정보수정
# 5. 프로그램종료
#
# 로그인 메뉴에 진입하였습니다.
#
# ...
# MBC 아카데미 회원 관리 프로그램
# ...
# 1. 회원가입
# 2. 로그인
# 3. 회원보기
# 4. 내정보수정
# 5. 프로그램종료
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[99], line 25
#      23 while run :
#      24      print(menu)
# ---> 25      select = input("1~5 숫자를 입력하여 메뉴를 선택하세요 : ")
#      26      if select == "1" :
#      27          print("회원가입 메뉴에 진입하였습니다.")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
# ...

# %%
if id in ids:
    ids = ids.index(id)
    if passwords[idx] == pw:
        login_user = idx
        print(f"{names[idx]}님 로그인 성공")

        if admins[idx]:
            print("▶관리자 계정입니다.◀")
        else:
            print("▶일반회원 계정입니다.◀")
    else:
        print("비밀번호가 틀렸습니다.")
else:
    print("존재하지 않는 ID 입니다.")
