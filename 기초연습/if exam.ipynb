# %%
#if문은 조건문으로 판단하여 참(True) 거짓(False)로 판단하는 코드
#if 조건 :
#      조건이 참일 때 실행하는 실행문을 적는다.
#elif 조건 :
#    위 조건이 false 일때 또 비교하는 조건문
#else :
#    위 조건이 모두 해당하지 않을 때 실행하는 조건문

# 학점 계산용 코드
avg = int(input("평균을 입력하세요 >>>"))
if avg >= 90:
    grage = "A"

elif avg >= 80:
    grade = "B"

elif avg >= 70:
    grade = "C"

else:
    grade = "F"

print("귀하의 등급은 : " + grade + "입니다.")

# %%
money = True
if money:
    print("택시를 타고 가라")
else:
    print("걸어 가라")
# Out:
# 택시를 타고 가라

# %%
money = True
if money:
    print("택시를")
print("타고")
    print("가라")
# Out:
#   Cell In[5], line 5
#     print("가라")
#     ^
# IndentationError: unexpected indent

# %%
money = True
if money:
    print("택시를")
    print("타고")
        print("가라")
# Out:
#   Cell In[6], line 5
#     print("가라")
#     ^
# IndentationError: unexpected indent

# %%
money = True
if money:
# Out:
#   Cell In[10], line 2
#     if money:
#              ^
# SyntaxError: incomplete input

# %%
x = 3
y = 2
x > y
# Out:
# True

# %%
x < y
# Out:
# False

# %%
x == y
# Out:
# False

# %%
x != y
# Out:
# True

# %%
money = 2000
if money >= 3000:
    print("택시를 타고 가라")

# %%
idx = ids.index(id)

            # 비밀번호 입력을 위한 무한 루프 시작
            while True:
                pw = input("패스워드를 입력하세요 :")
                if passwords[idx] == pw:
                    login_user = idx
                    print(f"{names[idx]}님 로그인 성공\n3초뒤 메인화면으로 이동합니다.")
                    time.sleep(3)
                    break # 비밀번호 맞으면 안쪽 루프 탈출
                else:
                    # 틀렸을 때 빠져나가지 않고 다시 입력받음
                    print("입력한 패스워드가 맞지 않습니다.\n다시 입력하세요.")

            # 비밀번호 맞아서 탈출했으므로 아이디 입력 루프도 탈출
            break

        else:
            print("\n입력한 ID는 회원가입 되어있지 않습니다.\n3초뒤 메인화면으로 이동합니다.")
            time.sleep(3)
            break
💡 주요 변경 사항 및 팁
while True:의 활용: 비밀번호를 맞출 때까지 계속 물어봐야 하므로 while passwords[idx] == pw: 대신 while True:를 사용하고, 내부에 if문을 두어 성공 시에만 break를 거는 것이 논리적으로 명확합니다.

current_count를 활용한 입력 제한: (아까 질문하신 current_count를 여기서 활용해볼 수 있습니다!) 비밀번호를 계속 틀려도 무한히 입력하게 두는 대신, 3회나 5회로 제한을 두고 싶을 때 활용합니다.

Python

# 활용 예시: 비밀번호 3회 제한
fail_count = 0  # 현재 틀린 횟수 추적
while fail_count < 3:
    pw = input("패스워드를 입력하세요 :")
    if passwords[idx] == pw:
        # 로그인 성공 로직
        break
    else:
        fail_count += 1
        print(f"패스워드가 틀렸습니다. (현재 {fail_count}/3회)")

if fail_count == 3:
    print("비밀번호를 3회 초과 입력하여 메인으로 돌아갑니다.")
비밀번호 입력 횟수 제한 기능을 추가해 보고 싶으신가요? 원하신다면 위 로직을 전체 코드에 맞춰 다시 정리해 드릴 수 있습니다.

# %%
#Python

import re

def validate_info(data):
    # 정규 표현식 패턴: 숫자3자리 + 하이픈 + 숫자2자리
    pattern = r'^\d{3}-\d{2}$'

    if re.match(pattern, data):
        print("입력 성공: 올바른 형식입니다.")
        return True
    else:
        print("경고: 형식이 맞지 않습니다. '000-00' 형태로 6자리를 입력해주세요.")
        return False

# 테스트
validate_info("320-00")  # 성공
validate_info("3200-0")  # 경고
validate_info("ABC-00")  # 경고
# Out:
# 입력 성공: 올바른 형식입니다.
# 경고: 형식이 맞지 않습니다. '000-00' 형태로 6자리를 입력해주세요.
# 경고: 형식이 맞지 않습니다. '000-00' 형태로 6자리를 입력해주세요.
# False

# %%
#나중에 사용하게 될 지 모르지만 데이터 정렬에서 정말 중요한 함수
# sorted_data = sorted(combined_data, key=lambdax: x
